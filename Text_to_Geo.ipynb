# %% [markdown]
# <a href="https://colab.research.google.com/github/EtzionR/LM4GeoAI/blob/main/Text_to_Geo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ex 2: Text 2 Geo Data
# ### created by Etzion Harari | Geo-AI Course
#
# [**https://github.com/EtzionR/LM4GeoAI**](https://github.com/EtzionR/LM4GeoAI)

# %% [markdown]
# ## Imports

# %%
from transformers import pipeline, AutoModelForTokenClassification, AutoTokenizer
from geopy.geocoders import Nominatim
from time import sleep as wait
from tqdm import tqdm

import networkx as nx
import pandas as pd
import folium
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %% [markdown]
# ## Clone git Repo
# [https://github.com/EtzionR/NLP4GeoAI](https://github.com/EtzionR/NLP4GeoAI)

# %%
# %%bash
# rm -rf NLP4GeoAI
# git clone https://github.com/EtzionR/NLP4GeoAI.git
# Out:
# Cloning into 'NLP4GeoAI'...

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('NLP4GeoAI/data.csv')

print(f'Dataframe shape: {df.shape}')

df.head()
# Out:
# Dataframe shape: (23072, 2)
#                                                 Text      Source
# 0  Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...  ontonotes5
# 1  Rules that set standards for products or gover...  ontonotes5
# 2  Determining when handicapped access is require...  ontonotes5
# 3  ``It's very costly and time-consuming ,'' says...  ontonotes5
# 4  Next to medical insurance, ``costs of complian...  ontonotes5

# %% [markdown]
# ## Activate NER model
# [https://huggingface.co/dslim/distilbert-NER](https://huggingface.co/dslim/distilbert-NER)

# %%
MODEL = "dslim/bert-base-NER"
TEXT = "Sam Altman visited OpenAI in San Francisco."

ner = pipeline("ner",
               model=MODEL,
               aggregation_strategy='average')

output = ner(TEXT)

print('\n\n\nNER output:\n\n')

pd.DataFrame(output)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu
# NER output:
#   entity_group     score           word  start  end
# 0          PER  0.999328     Sam Altman      0   10
# 1          ORG  0.664299         OpenAI     19   25
# 2          LOC  0.999392  San Francisco     29   42

# %% [markdown]
# ## Run NER on the entire corpus

# %%
P = .1 # Run NER only on P% of df entries

outputs = []

for text, source in tqdm(df[:int(len(df)*P)].values):
    entites = ner(text)

    for entity in entites:

        entity['source'] = source
        entity['text'] = text

        outputs.append(entity)

outputs = pd.DataFrame(outputs)

print(f'\n\nNER output shape: {outputs.shape}\n')

outputs
# Out:
# 100%|██████████| 2307/2307 [06:55<00:00,  5.55it/s]
# NER output shape: (6644, 7)
#      entity_group     score               word  start  end      source  \
# 0             PER  0.999573     Malcolm Wallop     16   30  ontonotes5
# 1             ORG  0.500653                LRB     32   35  ontonotes5
# 2             LOC  0.879631                  R     37   38  ontonotes5
# 3             LOC  0.428097                Wyo     41   44  ontonotes5
# 4             ORG  0.499855                RRB     47   50  ontonotes5
# ...           ...       ...                ...    ...  ...         ...
# 6639          LOC  0.995469     Western Europe    152  166  ontonotes5
# 6640          PER  0.466073              Krenz      4    9  ontonotes5
# 6641          ORG  0.960657              Party     68   73  ontonotes5
# 6642          ORG  0.998935  Central Committee     87  104  ontonotes5
# 6643          LOC  0.999184        East Berlin    117  128  ontonotes5
#
#                                                    text
# 0     Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...
# 1     Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...
# 2     Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...
# 3     Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...
# 4     Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...
# ...                                                 ...
# 6639  It raises the long-cherished hopes of many Ger...
# 6640  Mr. Krenz, 52, was named the new party chief j...
# 6641  Mr. Krenz, 52, was named the new party chief j...
# 6642  Mr. Krenz, 52, was named the new party chief j...
# 6643  Mr. Krenz, 52, was named the new party chief j...
#
# [6644 rows x 7 columns]

# %% [markdown]
# ## Display the Top K locations from the corpus

# %%
k = 10

top_k_locations = outputs[outputs.entity_group=='LOC'].word.value_counts().head(k).reset_index()
top_k_locations
# Out:
#           word  count
# 0        U. S.    387
# 1     New York    154
# 2        Japan     69
# 3   California     64
# 4        China     55
# 5       London     45
# 6       Poland     41
# 7      Britain     41
# 8   Washington     40
# 9  Los Angeles     38

# %% [markdown]
# ## Use Nominatim package to geocode example place name

# %%
example = "Tel Aviv, Israel"

geolocator = Nominatim(user_agent="GeoAI_Course_Geocoder", timeout=10)

location = geolocator.geocode(example)

print(f'Location full adress:\n{location.address}\n')
print(f'WGS84 GEO X = {round(location.longitude,6)}, Y = {round(location.latitude,6)}')
# Out:
# Location full adress:
# תל־אביב–יפו, נפת תל אביב, מחוז תל אביב, ישראל
#
# WGS84 GEO X = 34.781806, Y = 32.0853

# %% [markdown]
# ## Geocode the Top K place names

# %%
time_gap = 1.25

x_coords = []
y_coords = []

for placename in tqdm(top_k_locations.word):
    loc = geolocator.geocode(placename)

    x_coords.append(loc.longitude)
    y_coords.append(loc.latitude)

    wait(time_gap)

top_k_locations['x'] = x_coords
top_k_locations['y'] = y_coords

top_k_locations
# Out:
# 100%|██████████| 10/10 [00:21<00:00,  2.12s/it]
#           word  count           x          y
# 0        U. S.    387 -100.445882  39.783730
# 1     New York    154  -74.006015  40.712728
# 2        Japan     69  139.239418  36.574844
# 3   California     64 -118.755997  36.701463
# 4        China     55  104.999927  35.000074
# 5       London     45   -0.127765  51.507446
# 6       Poland     41   19.134422  52.215933
# 7      Britain     41   -1.918153  54.315159
# 8   Washington     40  -77.036543  38.895037
# 9  Los Angeles     38 -118.242766  34.053691

# %% [markdown]
# ## Create folimap on the Top K places in the Corpus

# %%
fmap = folium.Map(location=[0, 0], zoom_start=3)

places = []
place_to_xy = {}

for name,x,y in zip(top_k_locations.word, top_k_locations.x, top_k_locations.y):
    folium.Marker([y,x], popup=name, tooltip=name).add_to(fmap)
    places.append(name)
    place_to_xy[name] = (y, x)

fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6a7cca34270359424ba03d74b0e2f9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6a7cca34270359424ba03d74b0e2f9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6a7cca34270359424ba03d74b0e2f9e = L.map(
#                 &quot;map_f6a7cca34270359424ba03d74b0e2f9e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e6923d6a2a3d6ee3b9ea153ad6a2374 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e6923d6a2a3d6ee3b9ea153ad6a2374.addTo(map_f6a7cca34270359424ba03d74b0e2f9e);
#
#
#             var marker_024e4861b274ac5268adaee7834ad7d6 = L.marker(
#                 [39.7837304, -100.445882],
#                 {
# }
#             ).addTo(map_f6a7cca34270359424ba03d74b0e2f9e);
#
#
#         var popup_f97d6d613239e1cfd73a2c897360f974 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_015ef1e02346d9373aa549b02f5ca1aa = $(`&lt;div id=&quot;html_015ef1e02346d9373aa549b02f5ca1aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;U. S.&lt;/div&gt;`)[0];
#                 popup_f97d6d613239e1cfd73a2c897360f974.setContent(html_015ef1e02346d9373aa549b02f5ca1aa);
#
#
#
#         marker_024e4861b274ac5268adaee7834ad7d6.bindPopup(popup_f97d6d613239e1cfd73a2c897360f974)
#         ;
#
#
#
#
#             marker_024e4861b274ac5268adaee7834ad7d6.bindTooltip(
#                 `&lt;div&gt;
#                      U. S.
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_421a2ebecb9f7f7c92b2092bc6b54a83 = L.marker(
#                 [40.7127281, -74.0060152],
#                 {
# }
#             ).addTo(map_f6a7cca34270359424ba03d74b0e2f9e);
#
#
#         var popup_6e4e6c28528d08406cda7888fa5b834c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b72c911b525b5f151f5acb99f055f9b6 = $(`&lt;div id=&quot;html_b72c911b525b5f151f5acb99f055f9b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York&lt;/div&gt;`)[0];
#                 popup_6e4e6c28528d08406cda7888fa5b834c.setContent(html_b72c911b525b5f151f5acb99f055f9b6);
#
#
#
#         marker_421a2ebecb9f7f7c92b2092bc6b54a83.bindPopup(popup_6e4e6c28528d08406cda7888fa5b834c)
#         ;
#
#
#
#
#             marker_421a2ebecb9f7f7c92b2092bc6b54a83.bindTooltip(
#                 `&lt;div&gt;
#                      New York
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f5d7e2b3f2194c54d6a348474135089f = L.marker(
#                 [36.5748441, 139.2394179],
#                 {
# }
#             ).addTo(map_f6a7cca34270359424ba03d74b0e2f9e);
#
#
#         var popup_cfd7b56b3cc13693bfe8bcf35f58befc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c48aa6604be005b02c0962ba96a9030 = $(`&lt;div id=&quot;html_7c48aa6604be005b02c0962ba96a9030&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Japan&lt;/div&gt;`)[0];
#                 popup_cfd7b56b3cc13693bfe8bcf35f58befc.setContent(html_7c48aa6604be005b02c0962ba96a9030);
#
#
#
#         marker_f5d7e2b3f2194c54d6a348474135089f.bindPopup(popup_cfd7b56b3cc13693bfe8bcf35f58befc)
#         ;
#
#
#
#
#             marker_f5d7e2b3f2194c54d6a348474135089f.bindTooltip(
#                 `&lt;div&gt;
#                      Japan
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_845c96560dff7edc7ffc3da6bc3d2265 = L.marker(
#                 [36.7014631, -118.755997],
#                 {
# }
#             ).addTo(map_f6a7cca34270359424ba03d74b0e2f9e);
#
#
#         var popup_b4b345cdd551fc1d8c3fb33e9b239739 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_037836c4172f0d770823bda130eb049e = $(`&lt;div id=&quot;html_037836c4172f0d770823bda130eb049e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;California&lt;/div&gt;`)[0];
#                 popup_b4b345cdd551fc1d8c3fb33e9b239739.setContent(html_037836c4172f0d770823bda130eb049e);
#
#
#
#         marker_845c96560dff7edc7ffc3da6bc3d2265.bindPopup(popup_b4b345cdd551fc1d8c3fb33e9b239739)
#         ;
#
#
#
#
#             marker

# %% [markdown]
# ## Construct a Graph from the pair locations entities

# %%
topk_places = set(places)

edge_weight = {}

G = nx.Graph()

sub = outputs[['text', 'entity_group', 'word']]
sub['merged'] = [(entity, typ) for _, typ, entity in sub.values]

sub = pd.pivot_table(sub[['text', 'merged']], index='text', aggfunc=set)

for entity_set in sub.merged[sub.merged.str.len()>1]:

    entity_list = [*entity_set]

    for i in range(len(entity_list)):
        for j in range(i+1, len(entity_list)):
            placei = entity_list[i][0]
            placej = entity_list[j][0]
            if placei in topk_places and placej in topk_places:
                G.add_edge(placei,
                           placej)
                edge_weight[(placei, placej)] = edge_weight.get((placei, placej), 0) + 1


print(f'\n\n\nConnections Graph created!\n|V| = {len(G.nodes)}\n|E| = {len(G.edges)}\n\n')
# Out:
# Connections Graph created!
# |V| = 9
# |E| = 15
# /tmp/ipython-input-1186469424.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub['merged'] = [(entity, typ) for _, typ, entity in sub.values]

# %% [markdown]
# ## Display the Graph on the MAP

# %%
fmap = folium.Map(location=[0, 0], zoom_start=3)

for name,x,y in zip(top_k_locations.word, top_k_locations.x, top_k_locations.y):
    folium.Marker([y,x], popup=name, tooltip=name,icon = folium.Icon(color="blue") ).add_to(fmap)

for i,j in G.edges:
    if (i,j) in edge_weight:
        folium.PolyLine(locations=[place_to_xy[j],
                                   place_to_xy[i]],
                        color="blue",
                        opacity=0.3,
                        tooltip=f'Side 1: {i}<br>Side 2: {j}<br>Connections: {edge_weight[(i,j)]}',
                        weight=edge_weight[(i,j)]).add_to(fmap)

fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0becefc2171b9eb29f8a0eff3c3af430 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0becefc2171b9eb29f8a0eff3c3af430&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0becefc2171b9eb29f8a0eff3c3af430 = L.map(
#                 &quot;map_0becefc2171b9eb29f8a0eff3c3af430&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e41500df4c2706d59189d6232c672bb3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e41500df4c2706d59189d6232c672bb3.addTo(map_0becefc2171b9eb29f8a0eff3c3af430);
#
#
#             var marker_22da41b4983847af389c1e68cc709fa1 = L.marker(
#                 [39.7837304, -100.445882],
#                 {
# }
#             ).addTo(map_0becefc2171b9eb29f8a0eff3c3af430);
#
#
#             var icon_962b883925ee6f983459d6a24ba04fff = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_16f887ddb63f5d16436c3a025d7d37b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3f5e871bedb1dc03d7d1dcf4a6fbfa9 = $(`&lt;div id=&quot;html_e3f5e871bedb1dc03d7d1dcf4a6fbfa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;U. S.&lt;/div&gt;`)[0];
#                 popup_16f887ddb63f5d16436c3a025d7d37b3.setContent(html_e3f5e871bedb1dc03d7d1dcf4a6fbfa9);
#
#
#
#         marker_22da41b4983847af389c1e68cc709fa1.bindPopup(popup_16f887ddb63f5d16436c3a025d7d37b3)
#         ;
#
#
#
#
#             marker_22da41b4983847af389c1e68cc709fa1.bindTooltip(
#                 `&lt;div&gt;
#                      U. S.
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_22da41b4983847af389c1e68cc709fa1.setIcon(icon_962b883925ee6f983459d6a24ba04fff);
#
#
#             var marker_3615c980124e1f6981254c61bad3bc2b = L.marker(
#                 [40.7127281, -74.0060152],
#                 {
# }
#             ).addTo(map_0becefc2171b9eb29f8a0eff3c3af430);
#
#
#             var icon_53179ec37b8d13c6ae52175716fbe589 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3180e432e23320e51fa56660013f0840 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2376b2357d6b682cdf8e3079af4936d2 = $(`&lt;div id=&quot;html_2376b2357d6b682cdf8e3079af4936d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York&lt;/div&gt;`)[0];
#                 popup_3180e432e23320e51fa56660013f0840.setContent(html_2376b2357d6b682cdf8e3079af4936d2);
#
#
#
#         marker_3615c980124e1f6981254c61bad3bc2b.bindPopup(popup_3180e432e23320e51fa56660013f0840)
#         ;
#
#
#
#
#             marker_3615c980124e1f6981254c61bad3bc2b.bindTooltip(
#                 `&lt;div&gt;
#                      New York
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_3615c980124e1f6981254c61bad3bc2b.setIcon(icon_53179ec37b8d13c6ae52175716fbe589);
#
#
#             var marker_4d3cc9cd993a68071471a871c845e4e9 = L.marker(
#                 [36.5748441, 139.2394179],
#                 {
# }
#             ).addTo(map_0becefc2171b9eb29f8a0eff3c3af430);
#
#
#             var icon_65b9c926cdcaa9e9e24bd9f1df57d5d1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a580e04389864d1207934285c5b99b96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c9c6626071b1f02855957c514855f78 = $(`&lt;div id=&quot;html_5c9c6626071b1f02855957c514855f78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Japan&lt;

# %% [markdown]
# Create by Etzion Harari | Geo-AI Course | [https://github.com/EtzionR/LM4GeoAI](https://github.com/EtzionR/LM4GeoAI)
